# %% [markdown]
# # Example implementation of Amazon SageMaker Components for Kubeflow Pipelines

# %% [markdown]
# This example demonstrates development of a Kubeflow pipeline with a seperate component call for different Amazon SageMaker features. The pipeline will perform the following actions:
#
# * Hyperparameter optimization
# * Select best hyperparameters and increase epochs
# * Training model on the best hyperparameters
# * Create an Amazon SageMaker model
# * Deploy model

# %% [markdown]
# ## Install KFP, SageMaker SDK and other dependencies

# %%
# !pip install kfp --upgrade
# Out:
# Requirement already satisfied: kfp in /opt/conda/lib/python3.8/site-packages (1.8.11)
# Requirement already satisfied: kfp-server-api<2.0.0,>=1.1.2 in /opt/conda/lib/python3.8/site-packages (from kfp) (1.7.1)
# Requirement already satisfied: uritemplate<4,>=3.0.1 in /opt/conda/lib/python3.8/site-packages (from kfp) (3.0.1)
# Requirement already satisfied: pydantic<2,>=1.8.2 in /opt/conda/lib/python3.8/site-packages (from kfp) (1.9.0)
# Requirement already satisfied: kfp-pipeline-spec<0.2.0,>=0.1.13 in /opt/conda/lib/python3.8/site-packages (from kfp) (0.1.13)
# Requirement already satisfied: cloudpickle<3,>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from kfp) (2.0.0)
# Requirement already satisfied: strip-hints<1,>=0.1.8 in /opt/conda/lib/python3.8/site-packages (from kfp) (0.1.10)
# Requirement already satisfied: google-auth<2,>=1.6.1 in /opt/conda/lib/python3.8/site-packages (from kfp) (1.35.0)
# Requirement already satisfied: google-cloud-storage<2,>=1.20.0 in /opt/conda/lib/python3.8/site-packages (from kfp) (1.44.0)
# Requirement already satisfied: fire<1,>=0.3.1 in /opt/conda/lib/python3.8/site-packages (from kfp) (0.4.0)
# Requirement already satisfied: PyYAML<6,>=5.3 in /opt/conda/lib/python3.8/site-packages (from kfp) (5.4.1)
# Requirement already satisfied: docstring-parser<1,>=0.7.3 in /opt/conda/lib/python3.8/site-packages (from kfp) (0.13)
# Requirement already satisfied: typing-extensions<4,>=3.7.4 in /opt/conda/lib/python3.8/site-packages (from kfp) (3.10.0.2)
# Requirement already satisfied: google-api-python-client<2,>=1.7.8 in /opt/conda/lib/python3.8/site-packages (from kfp) (1.12.10)
# Requirement already satisfied: typer<1.0,>=0.3.2 in /opt/conda/lib/python3.8/site-packages (from kfp) (0.4.0)
# Requirement already satisfied: click<9,>=7.1.2 in /opt/conda/lib/python3.8/site-packages (from kfp) (8.0.3)
# Requirement already satisfied: jsonschema<4,>=3.0.1 in /opt/conda/lib/python3.8/site-packages (from kfp) (3.2.0)
# Requirement already satisfied: absl-py<2,>=0.9 in /opt/conda/lib/python3.8/site-packages (from kfp) (1.0.0)
# Requirement already satisfied: kubernetes<19,>=8.0.0 in /opt/conda/lib/python3.8/site-packages (from kfp) (18.20.0)
# Requirement already satisfied: Deprecated<2,>=1.2.7 in /opt/conda/lib/python3.8/site-packages (from kfp) (1.2.13)
# Requirement already satisfied: requests-toolbelt<1,>=0.8.0 in /opt/conda/lib/python3.8/site-packages (from kfp) (0.9.1)
# Requirement already satisfied: tabulate<1,>=0.8.6 in /opt/conda/lib/python3.8/site-packages (from kfp) (0.8.9)
# Requirement already satisfied: protobuf<4,>=3.13.0 in /opt/conda/lib/python3.8/site-packages (from kfp) (3.19.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from absl-py<2,>=0.9->kfp) (1.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.8/site-packages (from Deprecated<2,>=1.2.7->kfp) (1.13.3)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.8/site-packages (from fire<1,>=0.3.1->kfp) (1.1.0)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /opt/conda/lib/python3.8/site-packages (from google-api-python-client<2,>=1.7.8->kfp) (2.5.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /opt/conda/lib/python3.8/site-packages (from google-api-python-client<2,>=1.7.8->kfp) (0.20.4)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /opt/conda/lib/python3.8/site-packages (from google-api-python-client<2,>=1.7.8->kfp) (0.1.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from google-auth<2,>=1.6.1->kfp) (4.2.4)
# Requirement already satisfied: setuptools>=40.3.0 in /opt/conda/lib/python3.8/site-packages (from google-auth<2,>=1.6.1->kfp) (58.5.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.8/site-packages (from google-auth<2,>=1.6.1->kfp) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.8/site-packages (from google-auth<2,>=1.6.1->kfp) (4.8)
# Requirement already satisfied: google-resumable-media<3.0dev,>=1.3.0 in /opt/conda/lib/python3.8/site-packages (from google-cloud-storage<2,>=1.20.0->kfp) (2.2.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=1.6.0 in /opt/conda/lib/python3.8/site-packages (from google-cloud-storage<2,>=1.20.0->kfp) (2.2.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/conda/lib/python3.8/site-packages (from google-cloud-storage<2,>=1.20.0->kfp) (2.26.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema<4,>=3.0.1->kfp) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema<4,>=3.0.1->kfp) (21.2.0)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.8/site-packages (from kfp-server-api<2.0.0,>=1.1.2->kfp) (2.8.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.8/site-packages (from kfp-server-api<2.0.0,>=1.1.2->kfp) (2021.10.8)
# Requirement already satisfied: urllib3>=1.15 in /opt/conda/lib/python3.8/site-packages (from kfp-server-api<2.0.0,>=1.1.2->kfp) (1.26.7)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/conda/lib/python3.8/site-packages (from kubernetes<19,>=8.0.0->kfp) (1.2.1)
# Requirement already satisfied: requests-oauthlib in /opt/conda/lib/python3.8/site-packages (from kubernetes<19,>=8.0.0->kfp) (1.3.1)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.8/site-packages (from strip-hints<1,>=0.1.8->kfp) (0.37.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in /opt/conda/lib/python3.8/site-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.7.8->kfp) (1.54.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.8/site-packages (from google-resumable-media<3.0dev,>=1.3.0->google-cloud-storage<2,>=1.20.0->kfp) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/conda/lib/python3.8/site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client<2,>=1.7.8->kfp) (2.4.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.1->kfp) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage<2,>=1.20.0->kfp) (2.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage<2,>=1.20.0->kfp) (3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.8/site-packages (from requests-oauthlib->kubernetes<19,>=8.0.0->kfp) (3.2.0)

# %%
# !pip install sagemaker --upgrade
# Out:
# Requirement already satisfied: sagemaker in /opt/conda/lib/python3.8/site-packages (2.75.1)
# Requirement already satisfied: protobuf3-to-dict>=0.1.5 in /opt/conda/lib/python3.8/site-packages (from sagemaker) (0.1.5)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.8/site-packages (from sagemaker) (1.4.0)
# Requirement already satisfied: numpy>=1.9.0 in /opt/conda/lib/python3.8/site-packages (from sagemaker) (1.22.1)
# Requirement already satisfied: protobuf>=3.1 in /opt/conda/lib/python3.8/site-packages (from sagemaker) (3.19.4)
# Requirement already satisfied: google-pasta in /opt/conda/lib/python3.8/site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.8/site-packages (from sagemaker) (21.2)
# Requirement already satisfied: boto3>=1.20.21 in /opt/conda/lib/python3.8/site-packages (from sagemaker) (1.20.50)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /opt/conda/lib/python3.8/site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: pathos in /opt/conda/lib/python3.8/site-packages (from sagemaker) (0.2.8)
# Requirement already satisfied: importlib-metadata>=1.4.0 in /opt/conda/lib/python3.8/site-packages (from sagemaker) (4.10.1)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.8/site-packages (from sagemaker) (21.2.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /opt/conda/lib/python3.8/site-packages (from boto3>=1.20.21->sagemaker) (0.5.1)
# Requirement already satisfied: botocore<1.24.0,>=1.23.50 in /opt/conda/lib/python3.8/site-packages (from boto3>=1.20.21->sagemaker) (1.23.50)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.8/site-packages (from boto3>=1.20.21->sagemaker) (0.10.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.8/site-packages (from importlib-metadata>=1.4.0->sagemaker) (3.6.0)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging>=20.0->sagemaker) (2.4.7)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from protobuf3-to-dict>=0.1.5->sagemaker) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.8/site-packages (from pandas->sagemaker) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.8/site-packages (from pandas->sagemaker) (2.8.2)
# Requirement already satisfied: pox>=0.3.0 in /opt/conda/lib/python3.8/site-packages (from pathos->sagemaker) (0.3.0)
# Requirement already satisfied: ppft>=1.6.6.4 in /opt/conda/lib/python3.8/site-packages (from pathos->sagemaker) (1.6.6.4)
# Requirement already satisfied: multiprocess>=0.70.12 in /opt/conda/lib/python3.8/site-packages (from pathos->sagemaker) (0.70.12.2)
# Requirement already satisfied: dill>=0.3.4 in /opt/conda/lib/python3.8/site-packages (from pathos->sagemaker) (0.3.4)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/conda/lib/python3.8/site-packages (from botocore<1.24.0,>=1.23.50->boto3>=1.20.21->sagemaker) (1.26.7)

# %%
# !pip install tensorflow_datasets
# Out:
# Requirement already satisfied: tensorflow_datasets in /opt/conda/lib/python3.8/site-packages (4.5.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from tensorflow_datasets) (1.22.1)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.8/site-packages (from tensorflow_datasets) (1.1.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.8/site-packages (from tensorflow_datasets) (4.62.3)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.8/site-packages (from tensorflow_datasets) (1.0.0)
# Requirement already satisfied: importlib-resources in /opt/conda/lib/python3.8/site-packages (from tensorflow_datasets) (5.4.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow_datasets) (2.26.0)
# Requirement already satisfied: protobuf>=3.12.2 in /opt/conda/lib/python3.8/site-packages (from tensorflow_datasets) (3.19.4)
# Requirement already satisfied: tensorflow-metadata in /opt/conda/lib/python3.8/site-packages (from tensorflow_datasets) (1.6.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from tensorflow_datasets) (1.16.0)
# Requirement already satisfied: dill in /opt/conda/lib/python3.8/site-packages (from tensorflow_datasets) (0.3.4)
# Requirement already satisfied: promise in /opt/conda/lib/python3.8/site-packages (from tensorflow_datasets) (2.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.19.0->tensorflow_datasets) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=2.19.0->tensorflow_datasets) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.8/site-packages (from requests>=2.19.0->tensorflow_datasets) (2.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.19.0->tensorflow_datasets) (3.1)
# Requirement already satisfied: zipp>=3.1.0 in /opt/conda/lib/python3.8/site-packages (from importlib-resources->tensorflow_datasets) (3.6.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow-metadata->tensorflow_datasets) (1.54.0)

# %%
import kfp
from kfp import components
from kfp.components import func_to_container_op
from kfp import dsl
import time, os, json

# %% [markdown]
# ## Setup Kubeflow components for SageMaker Operators

# %%
sagemaker_hpo_op = components.load_component_from_url('https://raw.githubusercontent.com/kubeflow/pipelines/cb36f87b727df0578f4c1e3fe9c24a30bb59e5a2/components/aws/sagemaker/hyperparameter_tuning/component.yaml')
sagemaker_train_op = components.load_component_from_url('https://raw.githubusercontent.com/kubeflow/pipelines/cb36f87b727df0578f4c1e3fe9c24a30bb59e5a2/components/aws/sagemaker/train/component.yaml')
sagemaker_model_op = components.load_component_from_url('https://raw.githubusercontent.com/kubeflow/pipelines/cb36f87b727df0578f4c1e3fe9c24a30bb59e5a2/components/aws/sagemaker/model/component.yaml')
sagemaker_deploy_op = components.load_component_from_url('https://raw.githubusercontent.com/kubeflow/pipelines/cb36f87b727df0578f4c1e3fe9c24a30bb59e5a2/components/aws/sagemaker/deploy/component.yaml')

# %% [markdown]
# ## Start a SageMaker Session

# %%
import sagemaker
import boto3

sess = boto3.Session()
sm   = sess.client('sagemaker',region_name='us-west-2')
role = sagemaker.get_execution_role()
sagemaker_session = sagemaker.Session(boto_session=sess)
# Out:
# Couldn't call 'get_role' to get Role ARN from role name eksctl-eksdemo-eksctl-nodegroup-n-NodeInstanceRole-Y2P85GJ43UBH to get Role path.

# %%
# !which dsl-compile
# Out:
# /opt/conda/bin/dsl-compile

# %% [markdown]
# ## Prepare training datasets and upload to Amazon S3

# %%
bucket_name = 'q0h618-eks-ml-data'
job_folder      = 'jobs'
dataset_folder  = 'datasets'
local_dataset = 'cifar10'

# !python generate_cifar10_tfrecords_v2.py --data-dir {local_dataset}
# Out:
# 2022-02-09 13:54:45.444122: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-09 13:54:45.444150: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Download from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz and extract.
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:00<?, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:00<?, ? url/s]
# Dl Size...:   0%|                                     | 0/162 [00:00<?, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:00<?, ? url/s]
# Dl Size...:   1%|▏                            | 1/162 [00:00<02:12,  1.21 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:00<?, ? url/s]
# Dl Size...:   1%|▎                            | 2/162 [00:00<02:11,  1.21 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:00<?, ? url/s]
# Dl Size...:   2%|▌                            | 3/162 [00:00<02:10,  1.21 MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:00<?, ? url/s]
# Dl Size...:   2%|▋                            | 4/162 [00:00<00:31,  5.06 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:00<?, ? url/s]
# Dl Size...:   3%|▉                            | 5/162 [00:00<00:31,  5.06 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   4%|█                            | 6/162 [00:01<00:30,  5.06 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   4%|█▎                           | 7/162 [00:01<00:17,  8.62 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   5%|█▍                           | 8/162 [00:01<00:17,  8.62 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   6%|█▌                           | 9/162 [00:01<00:17,  8.62 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   6%|█▋                          | 10/162 [00:01<00:17,  8.62 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   7%|█▉                          | 11/162 [00:01<00:11, 13.09 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   7%|██                          | 12/162 [00:01<00:11, 13.09 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   8%|██▏                         | 13/162 [00:01<00:11, 13.09 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   9%|██▍                         | 14/162 [00:01<00:11, 13.09 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   9%|██▌                         | 15/162 [00:01<00:08, 16.73 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  10%|██▊                         | 16/162 [00:01<00:08, 16.73 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  10%|██▉                         | 17/162 [00:01<00:08, 16.73 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  11%|███                         | 18/162 [00:01<00:08, 16.73 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  12%|███▎                        | 19/162 [00:01<00:06, 20.90 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  12%|███▍                        | 20/162 [00:01<00:06, 20.90 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  13%|███▋                        | 21/162 [00:01<00:06, 20.90 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  14%|███▊                        | 22/162 [00:01<00:06, 22.01 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  14%|███▉                        | 23/162 [00:01<00:06, 22.01 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  15%|████▏                       | 24/162 [00:01<00:06, 22.01 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  15%|████▎                       | 25/162 [00:01<00:06, 22.01 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  16%|████▍                       | 26/162 [00:01<00:05, 25.75 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  17%|████▋                       | 27/162 [00:01<00:05, 25.75 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  17%|████▊                       | 28/162 [00:01<00:05, 25.75 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  18%|█████                       | 29/162 [00:01<00:05, 25.75 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  19%|█████▏                      | 30/162 [00:01<00:04, 27.19 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  19%|█████▎                      | 31/162 [00:01<00:04, 27.19 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  20%|█████▌                      | 32/162 [00:01<00:04, 27.19 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  20%|█████▋                      | 33/162 [00:01<00:04, 27.19 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:  21%|█████▉                      | 34/162 [00:01<00:04, 27.19 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  22%|██████                      | 35/162 [00:02<00:04, 29.78 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  22%|██████▏                     | 36/162 [00:02<00:04, 29.78 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  23%|██████▍                     | 37/162 [00:02<00:04, 29.78 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  23%|██████▌                     | 38/162 [00:02<00:04, 29.78 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  24%|██████▋                     | 39/162 [00:02<00:03, 32.09 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  25%|██████▉                     | 40/162 [00:02<00:03, 32.09 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  25%|███████                     | 41/162 [00:02<00:03, 32.09 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  26%|███████▎                    | 42/162 [00:02<00:03, 32.09 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  27%|███████▍                    | 43/162 [00:02<00:03, 33.08 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  27%|███████▌                    | 44/162 [00:02<00:03, 33.08 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  28%|███████▊                    | 45/162 [00:02<00:03, 33.08 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  28%|███████▉                    | 46/162 [00:02<00:03, 33.08 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  29%|████████                    | 47/162 [00:02<00:03, 33.68 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  30%|████████▎                   | 48/162 [00:02<00:03, 33.68 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  30%|████████▍                   | 49/162 [00:02<00:03, 33.68 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  31%|████████▋                   | 50/162 [00:02<00:03, 33.68 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  31%|████████▊                   | 51/162 [00:02<00:03, 35.21 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  32%|████████▉                   | 52/162 [00:02<00:03, 35.21 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  33%|█████████▏                  | 53/162 [00:02<00:03, 35.21 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  33%|█████████▎                  | 54/162 [00:02<00:03, 35.21 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  34%|█████████▌                  | 55/162 [00:02<00:02, 36.43 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  35%|█████████▋                  | 56/162 [00:02<00:02, 36.43 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  35%|█████████▊                  | 57/162 [00:02<00:02, 36.43 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  36%|██████████                  | 58/162 [00:02<00:02, 36.43 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  36%|██████████▏                 | 59/162 [00:02<00:02, 35.50 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  37%|██████████▎                 | 60/162 [00:02<00:02, 35.50 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  38%|██████████▌                 | 61/162 [00:02<00:02, 35.50 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  38%|██████████▋                 | 62/162 [00:02<00:02, 35.50 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  39%|██████████▉                 | 63/162 [00:02<00:02, 36.63 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  40%|███████████                 | 64/162 [00:02<00:02, 36.63 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  40%|███████████▏                | 65/162 [00:02<00:02, 36.63 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  41%|███████████▍                | 66/162 [00:02<00:02, 36.63 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  41%|███████████▌                | 67/162 [00:02<00:02, 37.50 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  42%|███████████▊                | 68/162 [00:02<00:02, 37.50 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  43%|███████████▉                | 69/162 [00:02<00:02, 37.50 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  43%|████████████                | 70/162 [00:02<00:02, 37.50 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:  44%|████████████▎               | 71/162 [00:02<00:02, 36.03 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  44%|████████████▍               | 72/162 [00:03<00:02, 36.03 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  45%|████████████▌               | 73/162 [00:03<00:02, 36.03 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  46%|████████████▊               | 74/162 [00:03<00:02, 36.03 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  46%|████████████▉               | 75/162 [00:03<00:02, 37.01 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  47%|█████████████▏              | 76/162 [00:03<00:02, 37.01 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  48%|█████████████▎              | 77/162 [00:03<00:02, 37.01 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  48%|█████████████▍              | 78/162 [00:03<00:02, 37.01 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  49%|█████████████▋              | 79/162 [00:03<00:02, 35.90 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  49%|█████████████▊              | 80/162 [00:03<00:02, 35.90 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  50%|██████████████              | 81/162 [00:03<00:02, 35.90 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  51%|██████████████▏             | 82/162 [00:03<00:02, 35.90 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  51%|██████████████▎             | 83/162 [00:03<00:02, 35.90 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  52%|██████████████▌             | 84/162 [00:03<00:02, 37.55 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  52%|██████████████▋             | 85/162 [00:03<00:02, 37.55 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  53%|██████████████▊             | 86/162 [00:03<00:02, 37.55 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  54%|███████████████             | 87/162 [00:03<00:01, 37.55 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  54%|███████████████▏            | 88/162 [00:03<00:02, 36.93 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  55%|███████████████▍            | 89/162 [00:03<00:01, 36.93 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  56%|███████████████▌            | 90/162 [00:03<00:01, 36.93 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  56%|███████████████▋            | 91/162 [00:03<00:01, 36.93 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  57%|███████████████▉            | 92/162 [00:03<00:01, 36.93 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  57%|████████████████            | 93/162 [00:03<00:01, 37.66 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  58%|████████████████▏           | 94/162 [00:03<00:01, 37.66 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  59%|████████████████▍           | 95/162 [00:03<00:01, 37.66 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  59%|████████████████▌           | 96/162 [00:03<00:01, 37.66 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  60%|████████████████▊           | 97/162 [00:03<00:01, 37.66 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  60%|████████████████▉           | 98/162 [00:03<00:01, 38.51 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  61%|█████████████████           | 99/162 [00:03<00:01, 38.51 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  62%|████████████████▋          | 100/162 [00:03<00:01, 38.51 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  62%|████████████████▊          | 101/162 [00:03<00:01, 38.51 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  63%|█████████████████          | 102/162 [00:03<00:01, 38.30 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  64%|█████████████████▏         | 103/162 [00:03<00:01, 38.30 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  64%|█████████████████▎         | 104/162 [00:03<00:01, 38.30 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  65%|█████████████████▌         | 105/162 [00:03<00:01, 38.30 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  65%|█████████████████▋         | 106/162 [00:03<00:01, 38.30 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  66%|█████████████████▊         | 107/162 [00:03<00:01, 39.10 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  67%|██████████████████         | 108/162 [00:03<00:01, 39.10 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:  67%|██████████████████▏        | 109/162 [00:03<00:01, 39.10 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  68%|██████████████████▎        | 110/162 [00:04<00:01, 39.10 MiB/s]
#
# Extraction completed...: 0 file [00:04, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  69%|██████████████████▌        | 111/162 [00:04<00:01, 39.31 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  69%|██████████████████▋        | 112/162 [00:04<00:01, 39.31 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  70%|██████████████████▊        | 113/162 [00:04<00:01, 39.31 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  70%|███████████████████        | 114/162 [00:04<00:01, 39.31 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  71%|███████████████████▏       | 115/162 [00:04<00:01, 39.31 MiB/s]
#
# Extraction completed...: 0 file [00:04, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  72%|███████████████████▎       | 116/162 [00:04<00:01, 38.26 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  72%|███████████████████▌       | 117/162 [00:04<00:01, 38.26 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  73%|███████████████████▋       | 118/162 [00:04<00:01, 38.26 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  73%|███████████████████▊       | 119/162 [00:04<00:01, 38.26 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  74%|████████████████████       | 120/162 [00:04<00:01, 38.26 MiB/s]
#
# Extraction completed...: 0 file [00:04, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  75%|████████████████████▏      | 121/162 [00:04<00:01, 39.43 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  75%|████████████████████▎      | 122/162 [00:04<00:01, 39.43 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  76%|████████████████████▌      | 123/162 [00:04<00:00, 39.43 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  77%|████████████████████▋      | 124/162 [00:04<00:00, 39.43 MiB/s]
#
# Extraction completed...: 0 file [00:04, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  77%|████████████████████▊      | 125/162 [00:04<00:00, 39.07 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  78%|█████████████████████      | 126/162 [00:04<00:00, 39.07 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  78%|█████████████████████▏     | 127/162 [00:04<00:00, 39.07 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  79%|█████████████████████▎     | 128/162 [00:04<00:00, 39.07 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  80%|█████████████████████▌     | 129/162 [00:04<00:00, 39.07 MiB/s]
#
# Extraction completed...: 0 file [00:04, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  80%|█████████████████████▋     | 130/162 [00:04<00:00, 40.14 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  81%|█████████████████████▊     | 131/162 [00:04<00:00, 40.14 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  81%|██████████████████████     | 132/162 [00:04<00:00, 40.14 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  82%|██████████████████████▏    | 133/162 [00:04<00:00, 40.14 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  83%|██████████████████████▎    | 134/162 [00:04<00:00, 40.14 MiB/s]
#
# Extraction completed...: 0 file [00:04, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  83%|██████████████████████▌    | 135/162 [00:04<00:00, 40.02 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  84%|██████████████████████▋    | 136/162 [00:04<00:00, 40.02 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  85%|██████████████████████▊    | 137/162 [00:04<00:00, 40.02 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  85%|███████████████████████    | 138/162 [00:04<00:00, 40.02 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  86%|███████████████████████▏   | 139/162 [00:04<00:00, 40.02 MiB/s]
#
# Extraction completed...: 0 file [00:04, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  86%|███████████████████████▎   | 140/162 [00:04<00:00, 39.15 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  87%|███████████████████████▌   | 141/162 [00:04<00:00, 39.15 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  88%|███████████████████████▋   | 142/162 [00:04<00:00, 39.15 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  88%|███████████████████████▊   | 143/162 [00:04<00:00, 39.15 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  89%|████████████████████████   | 144/162 [00:04<00:00, 39.15 MiB/s]
#
# Extraction completed...: 0 file [00:04, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  90%|████████████████████████▏  | 145/162 [00:04<00:00, 39.20 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  90%|████████████████████████▎  | 146/162 [00:04<00:00, 39.20 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  91%|████████████████████████▌  | 147/162 [00:04<00:00, 39.20 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  91%|████████████████████████▋  | 148/162 [00:04<00:00, 39.20 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:  92%|████████████████████████▊  | 149/162 [00:04<00:00, 39.20 MiB/s]
#
# Extraction completed...: 0 file [00:04, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:05<?, ? url/s]
# Dl Size...:  93%|█████████████████████████  | 150/162 [00:05<00:00, 39.98 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:05<?, ? url/s]
# Dl Size...:  93%|█████████████████████████▏ | 151/162 [00:05<00:00, 39.98 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:05<?, ? url/s]
# Dl Size...:  94%|█████████████████████████▎ | 152/162 [00:05<00:00, 39.98 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:05<?, ? url/s]
# Dl Size...:  94%|█████████████████████████▌ | 153/162 [00:05<00:00, 39.98 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:05<?, ? url/s]
# Dl Size...:  95%|█████████████████████████▋ | 154/162 [00:05<00:00, 39.98 MiB/s]
#
# Extraction completed...: 0 file [00:05, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:05<?, ? url/s]
# Dl Size...:  96%|█████████████████████████▊ | 155/162 [00:05<00:00, 40.27 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:05<?, ? url/s]
# Dl Size...:  96%|██████████████████████████ | 156/162 [00:05<00:00, 40.27 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:05<?, ? url/s]
# Dl Size...:  97%|██████████████████████████▏| 157/162 [00:05<00:00, 40.27 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:05<?, ? url/s]
# Dl Size...:  98%|██████████████████████████▎| 158/162 [00:05<00:00, 40.27 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:05<?, ? url/s]
# Dl Size...:  98%|██████████████████████████▌| 159/162 [00:05<00:00, 40.27 MiB/s]
#
# Extraction completed...: 0 file [00:05, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:05<?, ? url/s]
# Dl Size...:  99%|██████████████████████████▋| 160/162 [00:05<00:00, 39.20 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:05<?, ? url/s]
# Dl Size...:  99%|██████████████████████████▊| 161/162 [00:05<00:00, 39.20 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:05<?, ? url/s]
# Dl Size...: 100%|███████████████████████████| 162/162 [00:05<00:00, 39.20 MiB/s]
#
# Dl Completed...: 100%|██████████████████████████| 1/1 [00:05<00:00,  5.33s/ url]
# Dl Size...: 100%|███████████████████████████| 162/162 [00:05<00:00, 39.20 MiB/s]
#
# Dl Completed...: 100%|██████████████████████████| 1/1 [00:05<00:00,  5.33s/ url]
# Dl Size...: 100%|███████████████████████████| 162/162 [00:05<00:00, 39.20 MiB/s]
#
# Extraction completed...:   0%|                         | 0/1 [00:05<?, ? file/s]
#
# Dl Completed...: 100%|██████████████████████████| 1/1 [00:07<00:00,  5.33s/ url]
# Dl Size...: 100%|███████████████████████████| 162/162 [00:07<00:00, 39.20 MiB/s]
#
# Extraction completed...: 100%|█████████████████| 1/1 [00:07<00:00,  7.03s/ file]
# Dl Size...: 100%|███████████████████████████| 162/162 [00:07<00:00, 23.05 MiB/s]
# Dl Completed...: 100%|██████████████████████████| 1/1 [00:07<00:00,  7.03s/ url]
# Generating cifar10/train/train.tfrecords
# Generating cifar10/validation/validation.tfrecords
# Generating cifar10/eval/eval.tfrecords
# Done!

# %%
datasets = sagemaker_session.upload_data(bucket=bucket_name,path='cifar10', key_prefix='datasets/cifar10-dataset')

# If dataset is already in S3 use the dataset's path:
# datasets = 's3://{bucket_name}/{dataset_folder}/cifar10-dataset'

# %% [markdown]
# ## Upload Training Script to Amazon S3

# %%
# !tar cvfz sourcedir.tar.gz --exclude=".ipynb*" -C code .
source_s3 = sagemaker_session.upload_data(bucket=bucket_name, path='sourcedir.tar.gz', key_prefix='training-scripts')
print('\nUploaded to S3 location:')
print(source_s3)
# Out:
# ./
# ./inference.py
# ./cifar10-sagemaker-training.py
# ./requirements.txt
# ./model_def.py
#
# Uploaded to S3 location:
# s3://q0h618-eks-ml-data/training-scripts/sourcedir.tar.gz

# %% [markdown]
# ### A function to choose best performing model

# %%
def update_best_model_hyperparams(hpo_results, best_model_epoch = "80") -> str:
    import json
    r = json.loads(str(hpo_results))
    return json.dumps(dict(r,epochs=best_model_epoch))

get_best_hyp_op = func_to_container_op(update_best_model_hyperparams)

# %% [markdown]
# ## Build a pipeline

# %%
@dsl.pipeline(
    name='cifar10 hpo train deploy pipeline',
    description='cifar10 hpo train deploy pipeline using sagemaker'
)
def cifar10_hpo_train_deploy(region='us-west-2',
                           training_input_mode='File',
                           train_image='763104351884.dkr.ecr.us-west-2.amazonaws.com/tensorflow-training:1.15.2-gpu-py36-cu100-ubuntu18.04',
                           serving_image='763104351884.dkr.ecr.us-west-2.amazonaws.com/tensorflow-inference:1.15.2-cpu',
                           volume_size='50',
                           max_run_time='86400',
                           instance_type='ml.p3.2xlarge',
                           network_isolation='False',
                           traffic_encryption='False',
                           spot_instance='False',
                           channels='[ \
                    { \
                        "ChannelName": "train", \
                        "DataSource": { \
                            "S3DataSource": { \
                                "S3DataType": "S3Prefix", \
                                "S3Uri": "'+datasets+'/train", \
                                "S3DataDistributionType": "FullyReplicated" \
                            } \
                        }, \
                        "CompressionType": "None", \
                        "RecordWrapperType": "None" \
                    }, \
                    { \
                        "ChannelName": "validation", \
                        "DataSource": { \
                            "S3DataSource": { \
                                "S3DataType": "S3Prefix", \
                                "S3Uri": "'+datasets+'/validation", \
                                "S3DataDistributionType": "FullyReplicated" \
                            } \
                        }, \
                        "CompressionType": "None", \
                        "RecordWrapperType": "None" \
                    }, \
                    { \
                        "ChannelName": "eval", \
                        "DataSource": { \
                            "S3DataSource": { \
                                "S3DataType": "S3Prefix", \
                                "S3Uri": "'+datasets+'/eval", \
                                "S3DataDistributionType": "FullyReplicated" \
                            } \
                        }, \
                        "CompressionType": "None", \
                        "RecordWrapperType": "None" \
                    } \
                ]'
                          ):
    # Component 1
    hpo = sagemaker_hpo_op(
        region=region,
        image=train_image,
        training_input_mode=training_input_mode,
        strategy='Bayesian',
        metric_name='val_acc',
        metric_definitions='{"val_acc": "val_acc: ([0-9\\\\.]+)"}',
        metric_type='Maximize',
        static_parameters='{ \
            "epochs": "10", \
            "momentum": "0.9", \
            "weight-decay": "0.0002", \
            "model_dir":"s3://'+bucket_name+'/jobs", \
            "sagemaker_program": "cifar10-sagemaker-training.py", \
            "sagemaker_region": "us-west-2", \
            "sagemaker_submit_directory": "'+source_s3+'" \
        }',
        continuous_parameters='[ \
            {"Name": "learning-rate", "MinValue": "0.0001", "MaxValue": "0.1", "ScalingType": "Logarithmic"} \
        ]',
        categorical_parameters='[ \
            {"Name": "optimizer", "Values": ["sgd", "adam"]}, \
            {"Name": "batch-size", "Values": ["32", "128", "256"]}, \
            {"Name": "model-type", "Values": ["resnet", "custom"]} \
        ]',
        channels=channels,
        output_location=f's3://{bucket_name}/jobs',
        instance_type=instance_type,
        instance_count='1',
        volume_size=volume_size,
        max_num_jobs='16',
        max_parallel_jobs='2',
        max_run_time=max_run_time,
        network_isolation=network_isolation,
        traffic_encryption=traffic_encryption,
        spot_instance=spot_instance,
        role=role
    )
    
    # Component 2
    training_hyp = get_best_hyp_op(hpo.outputs['best_hyperparameters'])
    
    # Component 3
    training = sagemaker_train_op(
        region=region,
        image=train_image,
        training_input_mode=training_input_mode,
        hyperparameters=training_hyp.output,
        channels=channels,
        instance_type=instance_type,
        instance_count='1',
        volume_size=volume_size,
        max_run_time=max_run_time,
        model_artifact_path=f's3://{bucket_name}/jobs',
        network_isolation=network_isolation,
        traffic_encryption=traffic_encryption,
        spot_instance=spot_instance,
        role=role,
    )

    # Component 4
    create_model = sagemaker_model_op(
        region=region,
        model_name=training.outputs['job_name'],
        image=serving_image,
        model_artifact_url=training.outputs['model_artifact_url'],
        network_isolation=network_isolation,
        role=role
    )

    # Component 5
    prediction = sagemaker_deploy_op(
        region=region,
        model_name_1=create_model.output,
        instance_type_1='ml.m5.large'
    )

# %% [markdown]
# ## Compile and execute Pipeline

# %%
kfp.compiler.Compiler().compile(cifar10_hpo_train_deploy,'sm-hpo-train-deploy-pipeline.zip')

# %%
client = kfp.Client()
aws_experiment = client.create_experiment(name='sm-kfp-experiment')

exp_name    = f'cifar10-hpo-train-deploy-kfp-{time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())}'
my_run = client.run_pipeline(aws_experiment.id, exp_name, 'sm-hpo-train-deploy-pipeline.zip')
# Out:
# ERROR:root:Failed to read a token from file '/var/run/secrets/kubeflow/pipelines/token' ([Errno 2] No such file or directory: '/var/run/secrets/kubeflow/pipelines/token').
# WARNING:root:Failed to set up default credentials. Proceeding without credentials...
# <a href="/pipeline/#/experiments/details/1ad7a5e6-f627-4158-9bf9-b9a26315d218" target="_blank" >Experiment details</a>.
# <a href="/pipeline/#/runs/details/844d04b7-cd64-4d6a-80f5-3a9e72902396" target="_blank" >Run details</a>.

# %%
import json, boto3, numpy as np
client = boto3.client('runtime.sagemaker')

file_name = '1000_dog.png'
with open(file_name, 'rb') as f:
    payload = f.read()

response = client.invoke_endpoint(EndpointName='Endpoint-20200522021801-DR5P', 
                                   ContentType='application/x-image', 
                                   Body=payload)
pred = json.loads(response['Body'].read())['predictions']
labels = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
for l,p in zip(labels, pred[0]):
    print(l,"{:.4f}".format(p*100))
